# %% [markdown]
# <a href="https://colab.research.google.com/github/Logeometry/study/blob/main/%EA%B3%B5%ED%95%99%EC%9A%A9_%EA%B3%84%EC%82%B0%EA%B8%B0_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #공학용 계산기 개발의 필요성
# 본 프로젝트를 시작하게 된 이유는 많은 학생들이 잠깐 사용하기 위해
# 공학용 계산기를 사야하는 문제를 해결하기 위해 시작됐음.
# 또한 공학용 계산기를 사더라도 사용에 어려움을 겪는 학생이 많아
# 그나마 익숙한 형태로 사용하기 위해서임.

# %% [markdown]
# 지수 값 구하기

# %%
slider_value = 142  # @param {type: "slider", min: 100, max: 200}
x = 2  # @param {type: "number"}
y = 123  # @param {type: "number"}
date = '2010-11-05'  # @param {type: "date"}
pick_me = "monday"  # @param ['monday', 'tuesday', 'wednesday', 'thursday']
select_or_input = "apples" # @param ["apples", "bananas", "oranges"] {allow-input: true}
# @markdown ---

# %%
x6 = x*x*x*x*x*x
x6

if x6 > 2000000:
    print("너무 큰 수를 입력했습니다.")
